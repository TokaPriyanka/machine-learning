# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. data collection
# 2. data cleaning  60-70%
# 3. EDA (Exploratory data analysis)
# 4. data visualization
# 5. data preprocessing/ Feature Engineering
# 6. Model Training
# 7. Model testing
# 8. Model monitoring

# %% [markdown]
# **Data collection**

# %%
data = pd.read_csv("/content/mark.csv") # reading the file

# %% [markdown]
# **Data cleaning**

# %%
data.head() #it returns the first five rows of the DataFrame by default
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
data # this prints the whole data stored
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
data.columns # this prints all the columns of then data
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data.describe() #It provides a quick overview of the central tendency, dispersion, and shape of the dataset's distribution
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
data.info() #  It is useful for quickly understanding the structure and composition of the dataset, including the data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
data['Gender'].value_counts() # it is a count function
# Out:
# Gender
# Female    52727
# Male      51177
# Name: count, dtype: int64

# %%
data['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       84923
# disloyal Customer    18981
# Name: count, dtype: int64

# %%
data['Type of Travel'].value_counts()
# Out:
# Type of Travel
# Business travel    71655
# Personal Travel    32249
# Name: count, dtype: int64

# %%
data['Class'].value_counts()
# Out:
# Class
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: count, dtype: int64

# %%
data.duplicated() # used to identify duplicate rows in a DataFrame
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103904, dtype: bool

# %%
data[data.duplicated()] # used to filter and display only the duplicate rows from a DataFrame
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, Gender, Customer Type, Age, Type of Travel, Class, Flight Distance, Inflight wifi service, Departure/Arrival time convenient, Ease of Online booking, Gate location, Food and drink, Online boarding, Seat comfort, Inflight entertainment, On-board service, Leg room service, Baggage handling, Checkin service, Inflight service, Cleanliness, Departure Delay in Minutes, Arrival Delay in Minutes, satisfaction]
# Index: []
#
# [0 rows x 25 columns]

# %%
data.duplicated().sum() # used to count the number of duplicate rows in a DataFrame
# Out:
# 0

# %%
data['Arrival Delay in Minutes'].isnull().sum() # is used to count the number of missing (null) values
# Out:
# 310

# %%
data['Food and drink'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
data[data['Arrival Delay in Minutes'].isnull()]
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 213            213   49608  Female     Loyal Customer   38  Business travel
# 1124          1124   73442    Male     Loyal Customer   53  Personal Travel
# 1529          1529   71178    Male     Loyal Customer   39  Business travel
# 2004          2004   72940  Female  disloyal Customer   26  Business travel
# 2108          2108  116374  Female     Loyal Customer   24  Personal Travel
# ...            ...     ...     ...                ...  ...              ...
# 102067      102067   36729    Male     Loyal Customer   49  Personal Travel
# 102384      102384   71241    Male     Loyal Customer   58  Business travel
# 102552      102552   27684  Female  disloyal Customer   29  Business travel
# 102960      102960   36787    Male     Loyal Customer   58  Business travel
# 103540      103540   45022  Female     Loyal Customer   33  Personal Travel
#
# ...

# %%
data['Arrival Delay in Minutes'].fillna(0) # converted NaN to 0
# Out:
# 0         18.0
# 1          6.0
# 2          0.0
# 3          9.0
# 4          0.0
#           ...
# 103899     0.0
# 103900     0.0
# 103901    14.0
# 103902     0.0
# 103903     0.0
# Name: Arrival Delay in Minutes, Length: 103904, dtype: float64

# %%
data['Arrival Delay in Minutes'] = data['Arrival Delay in Minutes'].fillna(0)

# %%
data
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
data['Arrival Delay in Minutes'].isnull().sum()
# Out:
# 0

# %%
data.drop(columns = 'Unnamed: 0', inplace = True) # removed 'Unnamed: 0'

# %%
data
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0        70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         5047    Male  disloyal Customer   25  Business travel  Business
# 2       110028  Female     Loyal Customer   26  Business travel  Business
# 3        24026  Female     Loyal Customer   25  Business travel  Business
# 4       119299    Male     Loyal Customer   61  Business travel  Business
# ...        ...     ...                ...  ...              ...       ...
# 103899   94171  Female  disloyal Customer   23  Business travel       Eco
# 103900   73097    Male     Loyal Customer   49  Business travel  Business
# 103901   68825    Male  disloyal Customer   30  Business travel  Business
# 103902   54173  Female  disloyal Customer   22  Business travel       Eco
# 103903   62567    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
# tool used to convert categorical data into numerical format, making it suitable for machine learning models that require numerical input

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
# ...

# %% [markdown]
# **EDA (exploratory data analysis)and data visualisation**

# %%
data['satisfaction'].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: count, dtype: int64

# %%
data['Class'].value_counts()
# Out:
# Class
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: count, dtype: int64

# %%
data['Customer Type'].value_counts()
# Out:
# Customer Type
# Loyal Customer       84923
# disloyal Customer    18981
# Name: count, dtype: int64

# %% [markdown]
# #EDA (Exploratory data analysis)

# %%
import matplotlib.pyplot as plt
labels = ['neutral or dissatisfied', 'satisfied']
colors = ['#FF9999', '#66B3FF']
plt.pie(data['satisfaction'].value_counts(), labels=labels, autopct='%2.2f%%', colors=colors)
plt.title('Satisfaction Rate')
plt.legend(labels, loc='upper right')
plt.show()

# %%
data.groupby(['satisfaction', 'Gender']).size() # used to group the data by two categorical columns
# Out:
# satisfaction             Gender
# neutral or dissatisfied  Female    30193
#                          Male      28686
# satisfied                Female    22534
#                          Male      22491
# dtype: int64

# %%
p = sns.countplot(data = data, x = 'satisfaction', palette= 'Blues', hue='Gender')
plt.xlabel('Satisfaction')
plt.ylabel('Count of passenegers')
for container in p.containers:
    plt.bar_label(container)
plt.show()

# %%
data.groupby(['satisfaction', 'Customer Type']).size()
# Out:
# satisfaction             Customer Type
# neutral or dissatisfied  Loyal Customer       44390
#                          disloyal Customer    14489
# satisfied                Loyal Customer       40533
#                          disloyal Customer     4492
# dtype: int64

# %%
p = sns.countplot(data = data, x = 'satisfaction',palette= 'Blues', hue='Customer Type')
plt.xlabel('Satisfaction')
plt.ylabel('Count of passenegers')
for container in p.containers:
    plt.bar_label(container)
plt.show()

# %%
data.groupby(['satisfaction', 'Class']).size()
# Out:
# satisfaction             Class
# neutral or dissatisfied  Business    15185
#                          Eco         38044
#                          Eco Plus     5650
# satisfied                Business    34480
#                          Eco          8701
#                          Eco Plus     1844
# dtype: int64

# %%
p = sns.countplot(data = data, x = 'satisfaction',palette= 'Blues', hue='Class')
plt.xlabel('Satisfaction')
plt.ylabel('Count of passenegers')
for container in p.containers:
    plt.bar_label(container)
plt.show()

# %%
x = data['satisfaction'].value_counts().index
plot = sns.FacetGrid(data, col = 'Class')
p = plot.map(sns.countplot, 'satisfaction', order = x, palette = 'Blues')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# **Arrival time delay**

# %%
data['Arrival Delay in Minutes'].describe()
# Out:
# count    103904.000000
# mean         15.133392
# std          38.649776
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          13.000000
# max        1584.000000
# Name: Arrival Delay in Minutes, dtype: float64

# %%
plt.figure(figsize=(5,2))
sns.kdeplot( x = data['Arrival Delay in Minutes'], fill = True, color = 'pink')
# Out:
# <Axes: xlabel='Arrival Delay in Minutes', ylabel='Density'>

# %%
sns.violinplot(y = data['Arrival Delay in Minutes'], color='pink')
# Out:
# <Axes: ylabel='Arrival Delay in Minutes'>

# %%
sns.boxplot(y = data['Arrival Delay in Minutes'], color='pink')
# Out:
# <Axes: ylabel='Arrival Delay in Minutes'>

# %%
data['Arrival Delay in Minutes'].mode()
# Out:
# 0    0.0
# Name: Arrival Delay in Minutes, dtype: float64

# %% [markdown]
# **Departure time delay**

# %%
data['Departure Delay in Minutes'].value_counts().size
# Out:
# 446

# %%
data['Departure Delay in Minutes'].describe()
# Out:
# count    103904.000000
# mean         14.815618
# std          38.230901
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          12.000000
# max        1592.000000
# Name: Departure Delay in Minutes, dtype: float64

# %%
plt.figure(figsize=(5,2))
sns.kdeplot( x = data['Departure Delay in Minutes'], fill = True, color = 'pink')
# Out:
# <Axes: xlabel='Departure Delay in Minutes', ylabel='Density'>

# %%
sns.violinplot(y = data['Departure Delay in Minutes'], color='pink')
# Out:
# <Axes: ylabel='Departure Delay in Minutes'>

# %%
sns.boxplot(y = data['Departure Delay in Minutes'], color='pink')
# Out:
# <Axes: ylabel='Departure Delay in Minutes'>

# %% [markdown]
# **Data cleaning**

# %%
data = data.drop(columns = ['id'])

# %%
data.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# **Data analysis**

# %%
fig, axes = plt.subplots(figsize=(5,2))
fig.suptitle('Flight Timing and Schedule')
sns.countplot( x = data['Departure/Arrival time convenient'],palette = 'Blues')
plt.show()
# Out:
# <ipython-input-104-143098f44652>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( x = data['Departure/Arrival time convenient'],palette = 'Blues')

# %%
fig, axes = plt.subplots(3,2, figsize=(10,10))
fig.suptitle('Onboard Comfort and Amenities', fontsize = 15)
sns.countplot(x = data['Inflight wifi service'],ax=axes[0,0],palette = 'Blues')
sns.countplot(x = data['Food and drink'],ax=axes[0,1],palette = 'Blues')
sns.countplot(x = data['Seat comfort'],ax=axes[1,0],palette = 'Blues')
sns.countplot(x = data['Inflight entertainment'],ax=axes[1,1],palette ='Blues')
sns.countplot(x = data['Leg room service'],ax=axes[2,0],palette = 'Blues')
axes[2,1].remove()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-102-33f2c222074c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = data['Inflight wifi service'],ax=axes[0,0],palette = 'Blues')
# <ipython-input-102-33f2c222074c>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = data['Food and drink'],ax=axes[0,1],palette = 'Blues')
# <ipython-input-102-33f2c222074c>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = data['Seat comfort'],ax=axes[1,0],palette = 'Blues')
# <ipython-input-102-33f2c222074c>:6: FutureWarning:
#
# ...

# %%
fig, axes = plt.subplots( figsize=(5,2))
fig.suptitle('Boarding Process', fontsize = 15)
sns.countplot(x = data['Online boarding'],palette = 'Blues')
plt.show()
# Out:
# <ipython-input-103-0deae8006ecb>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = data['Online boarding'],palette = 'Blues')

# %%
sns.kdeplot(x= data['Online boarding'], hue = data['satisfaction'])
# Out:
# <Axes: xlabel='Online boarding', ylabel='Density'>

# %%
sns.scatterplot(x= data['Online boarding'], y = data['satisfaction'], hue = data['satisfaction'])
# Out:
# <Axes: xlabel='Online boarding', ylabel='satisfaction'>

# %%
obj_data = data.select_dtypes(include = 'object') # gives data which have objects
obj_data
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction
# 0       neutral or dissatisfied
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 4                     satisfied
# ...                         ...
# ...

# %% [markdown]
# **Data processing**

# %%
la = LabelEncoder() #converting categorical values into numerical values using label encoder
cols = ['Gender', 'Customer Type', 'Type of Travel']
for col in cols:
    data[col] = la.fit_transform(data[col])

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['Eco', 'Eco Plus', 'Business']])
data['Class'] = oe.fit_transform(data[['Class']])

oe = OrdinalEncoder(categories=[[ 'neutral or dissatisfied','satisfied']])
data['satisfaction'] = oe.fit_transform(data[['satisfaction']])

# %%
data
# Out:
#             id  Gender  Customer Type  Age  Type of Travel  Class  \
# 0        70172       1              0   13               1    1.0
# 1         5047       1              1   25               0    2.0
# 2       110028       0              0   26               0    2.0
# 3        24026       0              0   25               0    2.0
# 4       119299       1              0   61               0    2.0
# ...        ...     ...            ...  ...             ...    ...
# 103899   94171       0              1   23               0    0.0
# 103900   73097       1              0   49               0    2.0
# 103901   68825       1              1   30               0    2.0
# 103902   54173       0              1   22               0    0.0
# 103903   62567       1              0   27               0    2.0
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %% [markdown]
# **correlation between satisfaction rate and services provided**

# %%
data.corr()['satisfaction'].sort_values(ascending = False)
# Out:
# satisfaction                         1.000000
# Online boarding                      0.503557
# Class                                0.494471
# Inflight entertainment               0.398059
# Seat comfort                         0.349459
# On-board service                     0.322383
# Leg room service                     0.313131
# Cleanliness                          0.305198
# Flight Distance                      0.298780
# Inflight wifi service                0.284245
# Baggage handling                     0.247749
# Inflight service                     0.244741
# Checkin service                      0.236174
# Food and drink                       0.209936
# Ease of Online booking               0.171705
# Age                                  0.137167
# id                                   0.013734
# Gender                               0.012211
# Gate location                        0.000682
# Departure Delay in Minutes          -0.050494
# ...

# %%
data['Online boarding']
# Out:
# 0         3
# 1         3
# 2         5
# 3         2
# 4         5
#          ..
# 103899    2
# 103900    4
# 103901    1
# 103902    1
# 103903    1
# Name: Online boarding, Length: 103904, dtype: int64

# %%
mask = np.triu(np.ones_like(data.corr(), dtype=bool))
sns.set(style = 'white')
sns.heatmap(data= data.corr(),linewidths=0.5, mask = mask)
# Out:
# <Axes: >

# %% [markdown]
# #KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2)

# %%
print(len(y_train[y_train==1]))
print(len(y_train[y_train==0]))
# Out:
# 36072
# 47051

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
x_test
# Out:
# array([[-0.91086231, -0.98519201, -0.4727667 , ...,  1.30586973,
#         -0.3875318 , -0.39155376],
#        [-0.46685838, -0.98519201, -0.4727667 , ..., -0.98025121,
#         -0.3875318 , -0.28805978],
#        [ 0.45326063, -0.98519201, -0.4727667 , ..., -0.98025121,
#         -0.3875318 , -0.33980677],
#        ...,
#        [ 0.44314415,  1.01503056, -0.4727667 , ...,  0.54382941,
#         -0.28290389, -0.39155376],
#        [ 0.78790517, -0.98519201, -0.4727667 , ...,  1.30586973,
#         -0.3875318 , -0.39155376],
#        [ 0.01528921, -0.98519201, -0.4727667 , ..., -1.74229153,
#         -0.33521784,  0.04829566]])

# %%
print(type(x_test))
# Out:
# <class 'numpy.ndarray'>

# %%
y_predict = knn.predict(x_test)

# %%
knn.predict_proba(x_test)
# Out:
# array([[1. , 0. ],
#        [0.2, 0.8],
#        [1. , 0. ],
#        ...,
#        [0. , 1. ],
#        [0. , 1. ],
#        [1. , 0. ]])

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.97      0.94     11828
#          1.0       0.95      0.88      0.91      8953
#
#     accuracy                           0.93     20781
#    macro avg       0.93      0.92      0.93     20781
# weighted avg       0.93      0.93      0.93     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[11420,   408],
#        [ 1065,  7888]])

# %%
from sklearn.model_selection import cross_val_score, KFold
kf = KFold(n_splits=10, shuffle=True)
cross_val_results = cross_val_score(knn, x, y , cv=kf)
print(f'accuracy of all 10 folds: {cross_val_results}')
print(f'mean accuracy: {cross_val_results.mean()}')
# Out:
# accuracy of all 10 folds: [0.9282071  0.92753344 0.92647483 0.92965066 0.92935515 0.92897016
#  0.92810395 0.92694899 0.92646776 0.92897016]
# mean accuracy: 0.9280682207311075

# %% [markdown]
# #Naive bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_predict = gnb.predict(x_test)

# %%
gnb.predict_proba(x_test)
# Out:
# array([[8.55512290e-01, 1.44487710e-01],
#        [6.76769396e-02, 9.32323060e-01],
#        [9.99946496e-01, 5.35037398e-05],
#        ...,
#        [8.75299032e-04, 9.99124701e-01],
#        [2.81705176e-05, 9.99971829e-01],
#        [9.99999892e-01, 1.07809169e-07]])

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.89     11828
#          1.0       0.86      0.82      0.84      8953
#
#     accuracy                           0.87     20781
#    macro avg       0.87      0.86      0.86     20781
# weighted avg       0.87      0.87      0.87     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[10664,  1164],
#        [ 1607,  7346]])

# %%
cross_val_results = cross_val_score(gnb, x, y , cv=kf)
print(f'accuracy of all 10 folds: {cross_val_results}')
print(f'mean accuracy: {cross_val_results.mean()}')
# Out:
# accuracy of all 10 folds: [0.86863632 0.86930998 0.8605524  0.86613415 0.86159769 0.8639076
#  0.8626564  0.87006737 0.86631376 0.86256015]
# mean accuracy: 0.8651735838993708

# %% [markdown]
# #Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_predict = lr.predict(x_test)

# %%
lr.predict_proba(x_test)
# Out:
# array([[0.44964396, 0.55035604],
#        [0.50090423, 0.49909577],
#        [0.92392148, 0.07607852],
#        ...,
#        [0.0283014 , 0.9716986 ],
#        [0.04580422, 0.95419578],
#        [0.98088391, 0.01911609]])

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.91      0.89     11828
#          1.0       0.87      0.84      0.86      8953
#
#     accuracy                           0.88     20781
#    macro avg       0.88      0.87      0.88     20781
# weighted avg       0.88      0.88      0.88     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[10720,  1108],
#        [ 1422,  7531]])

# %%
cross_val_results = cross_val_score(lr, x, y , cv=kf)
print(f'accuracy of all 10 folds: {cross_val_results}')
print(f'mean accuracy: {cross_val_results.mean()}')
# Out:
# accuracy of all 10 folds: [0.87460302 0.87354441 0.87133096 0.87604658 0.87940327 0.87641963
#  0.87526468 0.87911453 0.87661213 0.87247353]
# mean accuracy: 0.8754812750243163

# %% [markdown]
# **Support vector machine**

# %%
from sklearn.svm import SVC

# %%
supportvm = SVC()

# %%
supportvm.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_predict = supportvm.predict(x_test)

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.97      0.96     11828
#          1.0       0.96      0.94      0.95      8953
#
#     accuracy                           0.96     20781
#    macro avg       0.96      0.96      0.96     20781
# weighted avg       0.96      0.96      0.96     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[11521,   307],
#        [  571,  8382]])

# %% [markdown]
# #Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = dtc.predict(x_test)

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     11828
#          1.0       0.93      0.94      0.94      8953
#
#     accuracy                           0.94     20781
#    macro avg       0.94      0.94      0.94     20781
# weighted avg       0.94      0.94      0.94     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[11243,   585],
#        [  565,  8388]])

# %%
cross_val_results = cross_val_score(dtc, x, y , cv=kf)
print(f'accuracy of all 10 folds: {cross_val_results}')
print(f'mean accuracy: {cross_val_results.mean()}')
# Out:
# accuracy of all 10 folds: [0.94889808 0.9484169  0.95130401 0.94370128 0.94456208 0.94408085
#  0.94744947 0.9452358  0.94408085 0.94860443]
# mean accuracy: 0.9466333751657636

# %% [markdown]
# #Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict = rfc.predict(x_test)

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97     11828
#          1.0       0.98      0.94      0.96      8953
#
#     accuracy                           0.96     20781
#    macro avg       0.97      0.96      0.96     20781
# weighted avg       0.96      0.96      0.96     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[11617,   211],
#        [  533,  8420]])

# %%
cross_val_results = cross_val_score(rfc, x, y , cv=kf)
print(f'accuracy of all 10 folds: {cross_val_results}')
print(f'mean accuracy: {cross_val_results.mean()}')
# Out:
# accuracy of all 10 folds: [0.96516216 0.96294871 0.96333365 0.9611202  0.96612127 0.96169394
#  0.96496631 0.96381136 0.96631376 0.96361886]
# mean accuracy: 0.9639090224762323
